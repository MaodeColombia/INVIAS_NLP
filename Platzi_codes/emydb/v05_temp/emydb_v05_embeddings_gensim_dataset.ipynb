# %% [markdown]
# # Word2Vec con Gensim

# %% [markdown]
# ## Instalación de librerías y carga de dataset

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (3.2.0)
# Requirement already satisfied: filelock in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\devel\.virtualenvs\unad-dbjylowd\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from gensim.models import Word2Vec
import pandas as pd
import re
from gensim.parsing.preprocessing import strip_punctuation, strip_numeric, strip_short, stem_text
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# -------------------------

# %%
from datasets import load_dataset

# Carga del dataset con confianza en el código remoto
dataset_corpus = load_dataset("large_spanish_corpus", "ParaCrawl", trust_remote_code=True) # or razones de seguridad, la biblioteca datasets no ejecuta ese código automáticamente a menos que explícitamente le indiques que confías en él.  `trust_remote_code=True`

# Ver las primeras filas del dataset
print(dataset_corpus)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 15510649
#     })
# })

# %%
dataset_corpus
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 15510649
#     })
# })

# %%
subset = dataset_corpus['train'].select(range(1000000))

# %%
subset[0:2]
# Out:
# {'text': ['lavado de cerebro a través de los medios de comunicación, y amenaza de fuerza a través de los militares.',
#   'Sin un constante aluvión de doble cañón, requiriendo la complicidad de los seres humanos para reprimir y engañar a sus semejantes, su tan cacareada magia rápidamente se desvanecería y se disiparía.']}

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\devel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\devel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\devel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Pre-procesamiento de texto

# %%
def clean_text(sentence_batch):
    # extrae el texto de la entrada
    text_list = sentence_batch['text']

    cleaned_text_list = []
    for text in text_list:
        # Convierte el texto a minúsculas
        text = text.lower()

        # Elimina URLs
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

        # Elimina las menciones @ y '#' de las redes sociales
        text = re.sub(r'\@\w+|\#\w+', '', text)

        # Elimina los caracteres de puntuación
        text = strip_punctuation(text)

        # Elimina los números
        text = strip_numeric(text)

        # Elimina las palabras cortas
        text = strip_short(text,minsize=2)

        # Elimina las palabras comunes (stop words)
        stop_words = set(stopwords.words('spanish'))
        word_tokens = word_tokenize(text)
        filtered_text = [word for word in word_tokens if word not in stop_words]

        cleaned_text_list.append(filtered_text)

    # Devuelve el texto limpio
    return {'text': cleaned_text_list}

# %%
sentences_corpus = subset.map(clean_text, batched=True)

# %%
sentences_corpus['text'][:3]
# Out:
# [['lavado',
#   'cerebro',
#   'través',
#   'medios',
#   'comunicación',
#   'amenaza',
#   'fuerza',
#   'través',
#   'militares'],
#  ['constante',
#   'aluvión',
#   'doble',
#   'cañón',
#   'requiriendo',
#   'complicidad',
#   'seres',
#   'humanos',
#   'reprimir',
#   'engañar',
#   'semejantes',
#   'tan',
#   'cacareada',
#   'magia',
#   'rápidamente',
#   'desvanecería',
#   'disiparía'],
#  ['realidad',
#   'nuevo',
#   'om',
#   'sólo',
#   'puede',
#   'mantener',
#   'ilusión',
#   'supremacía',
#   'mágica',
#   'siempre',
#   'reprima',
#   'desvíe',
#   'potencial',
#   'humano',
#   'mora',
#   'verdadera',
#   'magia',
#   'decir',
#   'capacidad',
#   'innata',
#   'especie',
#   'magia',
#   'interactiva',
#   'poderes',
#   'animación',
#   'diosa',
#   'planetaria']]

# %% [markdown]
# ## Carga y uso de modelo de embeddings Word2Vec

# %%
model = Word2Vec(sentences_corpus['text'], vector_size=100, window=5, min_count= 2, workers=6, sg=1)

# Podemos guardar el modelo para uso futuro
model.save("word2vec.model")

# %%
model.wv['rey']
# Out:
# array([ 3.49112034e-01, -3.26905102e-01, -9.20881629e-02,  9.24129635e-02,
#         2.72101551e-01,  2.16216236e-01, -2.78558172e-02,  5.16815960e-01,
#        -2.09546253e-01, -2.65958011e-01, -1.16155863e+00, -2.35676065e-01,
#        -2.12546647e-01,  6.98509395e-01, -7.87428617e-02,  4.79462519e-02,
#        -3.44289154e-01, -3.82320076e-01, -2.13814825e-01, -1.37528986e-01,
#         6.45280063e-01,  4.93542284e-01,  1.09555900e+00, -2.31672734e-01,
#         6.69048131e-01,  3.93133523e-04, -3.63920517e-02, -3.03488076e-01,
#        -1.77857205e-01, -5.91956861e-02,  6.95672259e-02,  6.76907480e-01,
#        -2.97301915e-02, -6.52781129e-01, -4.79972064e-02,  5.90684891e-01,
#        -1.23966232e-01, -3.59716207e-01, -6.53250664e-02, -8.60686362e-01,
#        -4.80895750e-02, -8.88880610e-01,  5.05257428e-01,  6.87248260e-03,
#        -1.18772320e-01,  1.62663877e-01, -2.38495246e-01, -4.86840457e-01,
#        -1.68601453e-01,  3.73677731e-01, -4.31218892e-01, -4.06613320e-01,
#         6.46060228e-01,  9.23964679e-01,  3.69867682e-02, -2.68934548e-01,
#        -1.82288941e-02, -1.04724564e-01, -2.71045297e-01, -5.35237908e-01,
#         3.04053545e-01, -4.70542489e-03,  3.73510391e-01, -6.49151057e-02,
#        -1.00490585e-01,  4.15036291e-01, -3.24497551e-01, -3.47189128e-01,
#        -5.43879449e-01, -1.50134936e-01,  1.32139310e-01,  4.33079332e-01,
#         9.53445315e-01, -8.45383525e-01,  2.66637266e-01,  1.95282295e-01,
#         3.22781146e-01, -1.76751569e-01, -2.22135007e-01, -1.26064226e-01,
#         2.63866842e-01, -8.73701692e-01, -8.25169265e-01, -1.93360686e-01,
#         3.16911310e-01,  2.27846131e-01, -1.67531401e-01, -1.24400988e-01,
#         1.52309164e-01,  7.87841856e-01,  3.54970545e-01,  3.25364321e-01,
#        -3.95668596e-01, -3.33475411e-01,  7.32949495e-01, -6.96132630e-02,
#         8.05249214e-01,  5.71048260e-01, -3.12970728e-01,  3.04957688e-01],
#       dtype=float32)

# %%
##comida, ser, reina, television
model.wv.most_similar(['television'],topn=3)
# Out:
# [('entertainment', 0.8574265241622925),
#  ('supren', 0.8553233742713928),
#  ('gsm', 0.8523894548416138)]

# %%
word_vectors = model.wv
vectors = word_vectors.vectors
words = word_vectors.index_to_key

# %%
#MMMO
display(word_vectors)
display(vectors)
display(words)
# Out:
# array([[ 0.02912564,  0.29023004, -0.00571955, ..., -0.4639063 ,
#          0.42262894,  0.6452081 ],
#        [-0.40865612,  0.24880876,  0.06341856, ..., -0.45689234,
#          0.1091899 ,  0.14513676],
#        [-0.49264842, -0.0562623 ,  0.11723249, ..., -0.7188871 ,
#          0.2465061 , -0.2177769 ],
#        ...,
#        [ 0.10998932,  0.12781289,  0.02438386, ..., -0.10849639,
#          0.04550839,  0.10815445],
#        [ 0.12090188,  0.04213727,  0.00180553, ..., -0.05744112,
#          0.01487436,  0.06404276],
#        [ 0.09379203,  0.10408198,  0.05195499, ..., -0.12108329,
#          0.03102642,  0.14544849]], dtype=float32)
# ['si',
#  'puede',
#  'ser',
#  '“',
#  '”',
#  'años',
#  'dios',
#  'usted',
#  'tiempo',
#  'así',
#  'vida',
#  'parte',
#  'mundo',
#  'cada',
#  'gran',
#  'dos',
#  'vez',
#  'pueden',
#  'después',
#  'hacer',
#  'sólo',
#  'lugar',
#  'personas',
#  'forma',
#  'día',
#  'mismo',
#  'todas',
#  'ahora',
#  'internet',
#  'sido',
#  'información',
#  '«',
#  'ciudad',
#  'bien',
#  '»',
#  'debe',
#  'iglesia',
#  'tierra',
#  'sistema',
#  'hace',
#  'aquí',
#  'hecho',
#  'través',
#  'grupo',
#  'casa',
#  'agua',
#  'ayuda',
#  'nuevo',
#  'país',
#  'año',
#  'general',
#  'dijo',
#  'cualquier',
#  'unidos',
#  'siempre',
#  'trabajo',
#  'sino',
#  'además',
#  'hoy',
#  'mejor',
#  'manera',
#  'hacia',
#  'medio',
#  'tan',
#  'menos',
#  'toda',
#  'cuenta',
#  'embargo',
#  'centro',
#  'mayor',
#  'tener',
#  'bajo',
#  'entonces',
#  'ver',
#  'hombre',
#  'mientras',
#  'ue',
#  'ejemplo',
#  'nueva',
#  'días',
#  'europa',
#  'momento',
#  'hotel',
#  'servicio',
#  'gente',
#  'posible',
#  'solo',
#  'decir',
#  'nombre',
#  'incluso',
#  'caso',
#  'servicios',
#  'importante',
#  'historia',
#  'desarrollo',
#  'dentro',
#  'tipo',
#  'países',
#  'problemas',
#  'poder',
#  'luego',
#  'niños',
#  'tres',
#  'corazón',
#  'energía',
#  'cosas',
#  'salud',
#  'europeo',
#  'ustedes',
#  'acerca',
#  'primera',
#  'productos',
#  'cómo',
#  'punto',
#  'luz',
#  'cuerpo',
#  'aunque',
#  'número',
#  'muchas',
#  'cambio',
#  'sitio',
#  'uso',
#  'nivel',
#  'según',
#  'podría',
#  'origen',
#  'persona',
#  'acuerdo',
#  'veces',
#  'europea',
#  'fin',
#  'seguridad',
#  'grandes',
#  'modo',
#  'proceso',
#  'web',
#  'datos',
#  'línea',
#  'padre',
#  'gobierno',
#  'diferentes',
#  'pueblo',
#  'gracias',
#  'internacional',
#  'problema',
#  'señor',
#  'dice',
#  'primer',
#  'contacto',
#  'guerra',
#  'tal',
#  'cerca',
#  'misma',
#  'calidad',
#  'alimentos',
#  'política',
#  '¿qué',
#  'nunca',
#  'san',
#  'experiencia',
#  'comisión',
#  'parlamento',
#  'fe',
#  'aquellos',
#  'proyecto',
#  'haber',
#  'campo',
#  'ofrece',
#  'mayoría',
#  'deben',
#  'presidente',
#  'familia',
#  'espíritu',
#  'amor',
#  'programa',
#  'hijos',
#  'hombres',
#  'realidad',
#  'miembros',
#  'camino',
#  'largo',
#  'social',
#  'aún',
#  'ley',
#  'mundial',
#  'jesús',
#  'naturaleza',
#  'flores',
#  'encuentra',
#  'noche',
#  'papa',
#  'espacio',
#  'control',
#  'hijo',
#  'verdad',
#  'personal',
#  'casi',
#  'millones',
#  'junto',
#  'palabras',
#  'zona',
#  'solución',
#  'relación',
#  'detalles',
#  'actividades',
#  'in',
#  'especial',
#  'empresas',
#  'médico',
#  'ello',
#  'unión',
#  'cristo',
#  'derechos',
#  'siendo',
#  'pasado',
#  'pues',
#  'atención',
#  'alta',
#  'investigación',
#  'humanos',
#  'lado',
#  'acceso',
#  'correo',
#  'especialmente',
#  'vista',
#  'debido',
#  'necesario',
#  'preguntas',
#  'obra',
#  'horas',
#  'todavía',
#  'ambiente',
#  'mujeres',
#  'grande',
#  'podemos',
#  'condiciones',
#  'paz',
#  'muerte',
#  'da',
#  'final',
#  'santo',
#  'capacidad',
#  'partir',
#  'página',
#  'base',
#  'objetivo',
#  'consejo',
#  'libro',
#  'electrónico',
#  'dar',
#  'situación',
#  'santa',
#  'propia',
#  'opciones',
#  'tomar',
#  'cantidad',
#  'va',
#  'cuanto',
#  'mar',
#  'versión',
#  'sociedad',
#  'conciencia',
#  'alrededor',
#  'nacional',
#  'ningún',
#  'realmente',
#  'jehová',
#  'natural',
#  'buena',
#  'total',
#  'partes',
#  'parece',
#  'imágenes',
#  'comunidad',
#  'área',
#  'mediante',
#  'arte',
#  'departamento',
#  'minutos',
#  'ninguna',
#  'varios',
#  'allí',
#  'mente',
#  'permite',
#  'siglo',
#  'sur',
#  'tratamiento',
#  'papel',
#  'mano',
#  'habitaciones',
#  'alto',
#  'nuevas',
#  'código',
#  'futuro',
#  'fuerza',
#  'principal',
#  'propio',
#  'dinero',
#  'frente',
#  'derecho',
#  'crecimiento',
#  'sangre',
#  'encontrar',
#  'mercado',
#  'causa',
#  'juego',
#  'resultados',
#  'dicho',
#  'nuevos',
#  'siguiente',
#  'tema',
#  'falta',
#  'actividad',
#  'cultura',
#  'empresa',
#  'mismos',
#  'ir',
#  'efecto',
#  'riesgo',
#  'hizo',
#  'palabra',
#  'alguna',
#  'crear',
#  'real',
#  'mas',
#  'apoyo',
#  'hacen',
#  'único',
#  'israel',
#  'ayudar',
#  'incluir',
#  'the',
#  'cuatro',
#  'edad',
#  'trata',
#  'grupos',
#  'medios',
#  'imagen',
#  'precio',
#  'música',
#  'público',
#  'cabo',
#  'hora',
#  'sector',
#  'dado',
#  'valor',
#  'estudio',
#  'jóvenes',
#  'favor',
#  'fácil',
#  'producción',
#  'común',
#  'respecto',
#  'pueda',
#  'norte',
#  'relaciones',
#  'menudo',
#  'comentarios',
#  'resultado',
#  'libre',
#  'razón',
#  'planeta',
#  'protección',
#  'equipo',
#  'varias',
#  'obtener',
#  'etc',
#  'importantes',
#  'llegar',
#  '¿cómo',
#  'meses',
#  'clientes',
#  'principales',
#  'recursos',
#  'aire',
#  'sol',
#  'oración',
#  'conocimiento',
#  'alma',
#  'acción',
#  'tras',
#  'cuales',
#  'existe',
#  'asegúrese',
#  'libertad',
#  'creación',
#  'habitación',
#  'roma',
#  'consumidor',
#  'pequeño',
#  'áreas',
#  'presente',
#  'fuerte',
#  'actual',
#  'enfermedad',
#  'rey',
#  'madre',
#  'movimiento',
#  'idea',
#  'producto',
#  'tales',
#  'saber',
#  'seguro',
#  'dirección',
#  'orden',
#  'cristianos',
#  'principio',
#  'ponerse',
#  'necesidad',
#  'interés',
#  'lugares',
#  'escuela',
#  'buen',
#  'interior',
#  'té',
#  'comunicación',
#  'pecado',
#  'tv',
#  'relacionado',
#  'cosa',
#  'navegador',
#  'mujer',
#  'padres',
#  'región',
#  'gestión',
#  'tarde',
#  'obras',
#  'cambios',
#  'casos',
#  'tecnología',
#  'aquel',
#  'estudios',
#  'sistemas',
#  'igual',
#  'humanidad',
#  'humana',
#  'color',
#  'física',
#  'seres',
#  'haga',
#  'cielo',
#  'proyectos',
#  'construcción',
#  'medida',
#  'respuesta',
#  'vínculo',
#  'quiere',
#  'única',
#  'red',
#  'central',
#  'educación',
#  'visuallightbox',
#  'material',
#  'significa',
#  'presencia',
#  'reserva',
#  'cinco',
#  'superior',
#  'demás',
#  'sigue',
#  'crisis',
#  'posibilidad',
#  'cáncer',
#  'operativo',
#  'puesto',
#  'pablo',
#  'van',
#  'incluyendo',
#  'población',
#  'solamente',
#  'plan',
#  'muestra',
#  'mejores',
#  'pequeña',
#  'situado',
#  'españa',
#  'formas',
#  'llamadas',
#  'pesar',
#  'egipto',
#  'manos',
#  'último',
#  'planta',
#  'usar',
#  'religión',
#  'socialistas',
#  'francia',
#  'mal',
#  'viaje',
#  'museo',
#  'primero',
#  'paso',
#  'ojos',
#  'realizar',
#  'pago',
#  'serie',
#  'utiliza',
#  'algún',
#  'semana',
#  'importancia',
#  'simplemente',
#  'voluntad',
#  'china',
#  'km',
#  'puntos',
#  'estudiantes',
#  'últimos',
#  'hablar',
#  'sociales',
#  'utilizar',
#  'llamado',
#  'seguir',
#  'universidad',
#  'segunda',
#  'mantener',
#  'medidas',
#  'instalaciones',
#  'necesidades',
#  'entrada',
#  'dolor',
#  'niño',
#  'sede',
#  'éxito',
#  'original',
#  'américa',
#  'efectos',
#  'difícil',
#  'organización',
#  'última',
#  'ciudadanos',
#  'vivir',
#  'evitar',
#  'juan',
#  'mayo',
#  'necesita',
#  'clase',
#  'fuente',
#  'visita',
#  'pocos',
#  'google',
#  'visto',
#  'octubre',
#  'carta',
#  'delante',
#  'formación',
#  'niveles',
#  'metros',
#  'completamente',
#  'pie',
#  'demócratas',
#  'totalmente',
#  'dejar',
#  'entrega',
#  'reino',
#  'reunión',
#  'llamar',
#  'global',
#  'políticas',
#  'período',
#  'especies',
#  'mil',
#  'mejorar',
#  'inglés',
#  'segundo',
#  'universo',
#  'conjunto',
#  'ii',
#  'directamente',
#  'alemania',
#  'cierto',
#  'enfermedades',
#  'industria',
#  '¿por',
#  'septiembre',
#  'teoría',
#  'junio',
#  'fecha',
#  'llevar',
#  'llamada',
#  'amigos',
#  'puedes',
#  'visión',
#  'cabeza',
#  'tipos',
#  'lista',
#  'podrá',
#  'isla',
#  'miles',
#  'exposición',
#  'estación',
#  'asuntos',
#  'alguien',
#  'sala',
#  'disponible',
#  'trabajar',
#  'acciones',
#  'europeos',
#  'haciendo',
#  'particular',
#  'diciembre',
#  'humano',
#  'poner',
#  'opción',
#  'local',
#  'encuentran',
#  'posición',
#  'allá',
#  'demasiado',
#  'unas',
#  'consumo',
#  'ideal',
#  'temas',
#  'modelo',
#  'puerta',
#  'medicamentos',
#  'siguientes',
#  'nadie',
#  'inicio',
#  'reducir',
#  'duda',
#  'amplia',
#  'río',
#  'puedo',
#  'marzo',
#  'podrían',
#  'justicia',
#  'recibir',
#  'oportunidad',
#  'animales',
#  'espiritual',
#  'italia',
#  'disfrutar',
#  'fuerzas',
#  'julio',
#  'tamaño',
#  'comida',
#  'toolani',
#  'frecuencia',
#  'zonas',
#  'creo',
#  'gracia',
#  'plantas',
#  'democrats',
#  'socialists',
#  'práctica',
#  'agradable',
#  'estructura',
#  'bueno',
#  'mes',
#  'noviembre',
#  'debemos',
#  'principios',
#  'época',
#  'pasar',
#  'disponibles',
#  'peso',
#  'primeros',
#  'función',
#  'unidad',
#  'prueba',
#  'llama',
#  'internacionales',
#  'eventos',
#  'madera',
#  'miembro',
#  'variedad',
#  'programas',
#  'informe',
#  'crédito',
#  'pronto',
#  'paris',
#  'conservación',
#  'france',
#  'diseño',
#  'mesa',
#  'mayores',
#  'transporte',
#  'materiales',
#  'cardenal',
#  'sabe',
#  'cultural',
#  'distancia',
#  'conocido',
#  'diferencia',
#  'locales',
#  'estancia',
#  'debería',
#  'superficie',
#  'judíos',
#  'dicen',
#  'análisis',
#  'enero',
#  'mañana',
#  'petición',
#  'elementos',
#  'bastante',
#  'términos',
#  'materia',
#  'incluye',
#  'estilo',
#  'abril',
#  'marco',
#  'completo',
#  'pequeños',
#  'áfrica',
#  'campos',
#  'ministerio',
#  'vistas',
#  'tiempos',
#  'claro',
#  'tratar',
#  'conocer',
#  'negocios',
#  'puedan',
#  'baño',
#  'pruebas',
#  'carácter',
#  'contenido',
#  'uicn',
#  'calle',
#  'deseo',
#  'escrito',
#  'evolución',
#  'ciento',
#  'anterior',
#  'toma',
#  'from',
#  'turismo',
#  'empleo',
#  'fondo',
#  'edificio',
#  'especie',
#  'ministro',
#  'compañía',
#  'objeto',
#  'actualmente',
#  'vino',
#  'plazo',
#  'suficiente',
#  'cargo',
#  'elección',
#  'cambiar',
#  'ciudades',
#  'presión',
#  'ciencia',
#  'oficial',
#  'menor',
#  'cocina',
#  'diciendo',
#  'requiere',
#  'dioses',
#  'privado',
#  've',
#  'pública',
#  'responsabilidad',
#  'familias',
#  'verdadero',
#  'completa',
#  'valores',
#  'revista',
#  'beneficios',
#  'economía',
#  'asociación',
#  'juegos',
#  '’',
#  'capital',
#  'obispo',
#  'velocidad',
#  'don',
#  'solar',
#  'pregunta',
#  'artículo',
#  'podía',
#  'costa',
#  'aumento',
#  'carne',
#  'existen',
#  'idioma',
#  'diferente',
#  'île',
#  'ambos',
#  'lucha',
#  'desayuno',
#  'voz',
#  'aguas',
#  'naturales',
#  'viene',
#  'compromiso',
#  'diálogo',
#  'antiguo',
#  'lleva',
#  'económica',
#  'iglesias',
#  'baja',
#  'pensamiento',
#  'naciones',
#  'existencia',
#  'masa',
#  'cama',
#  'piel',
#  'cliente',
#  'ofrecer',
#  'adelante',
#  'abierto',
#  'justo',
#  'científicos',
#  'cuestión',
#  'santos',
#  'ubicación',
#  'aplicación',
#  'reuniones',
#  'contrario',
#  'presenta',
#  'hacerlo',
#  'evento',
#  'trabajadores',
#  'profesionales',
#  'propiedad',
#  'playa',
#  'clic',
#  'seis',
#  'misión',
#  'exterior',
#  'siete',
#  'esperanza',
#  'cuidado',
#  'mensaje',
#  'mostrar',
#  'hojas',
#  'texto',
#  'partido',
#  'pensar',
#  'máximo',
#  'síntomas',
#  'hechos',
#  'oficina',
#  'clave',
#  'barato',
#  'hoteles',
#  'memoria',
#  'mucha',
#  'participación',
#  'decisión',
#  'supuesto',
#  'habla',
#  'dio',
#  'objetivos',
#  'concepto',
#  'hermanos',
#  'encuentro',
#  'aproximadamente',
#  'sitios',
#  'probablemente',
#  'referencia',
#  'políticos',
#  'almas',
#  'conferencia',
#  'medicamento',
#  'características',
#  'centros',
#  'febrero',
#  'cerebro',
#  'precios',
#  'altura',
#  'pagar',
#  'económico',
#  'comercio',
#  'venta',
#  'inteligencia',
#  'volver',
#  'joven',
#  'leyes',
#  'brasil',
#  'arriba',
#  'pequeñas',
#  'tradición',
#  'verdadera',
#  'documentos',
#  'aspectos',
#  'agosto',
#  'ideas',
#  'quieren',
#  'llegada',
#  'abajo',
#  'antigua',
#  'normas',
#  'eurodiputados',
#  'lejos',
#  'confianza',
#  'república',
#  'prácticas',
#  'finalmente',
#  'garantizar',
#  'simple',
#  'búsqueda',
#  'curso',
#  'derecha',
#  'procedimiento',
#  'rusia',
#  'usuarios',
#  'comunidades',
#  'media',
#  'pacientes',
#  'méxico',
#  'representa',
#  'excelente',
#  'oro',
#  'entorno',
#  'administración',
#  'entender',
#  'incluyen',
#  'moral',
#  'pueblos',
#  'director',
#  'enviado',
#  'máquina',
#  'precisamente',
#  'disposición',
#  'nacionales',
#  'sacerdotes',
#  'comer',
#  'jardín',
#  'swoboda',
#  'oriente',
#  'procesos',
#  'película',
#  'inmediatamente',
#  'recibido',
#  'físico',
#  'líder',
#  'soluciones',
#  'of',
#  'objetos',
#  'verde',
#  'gratis',
#  'expertos',
#  'influencia',
#  'capaz',
#  'dan',
#  'células',
#  'plaza',
#  'político',
#  'gobiernos',
#  'cristiana',
#  'resto',
#  'pedido',
#  'rápido',
#  'descripción',
#  'cooperación',
#  'éste',
#  'espera',
#  'motivo',
#  'fuego',
#  'rápidamente',
#  'creado',
#  'propios',
#  'católica',
#  'desea',
#  'sacerdote',
#  'esfuerzos',
#  'examen',
#  'comentario',
#  'diez',
#  'pide',
#  'comercial',
#  'continuación',
#  'enfoque',
#  'miedo',
#  'bad',
#  'método',
#  'inversión',
#  'organizaciones',
#  'libros',
#  'ocasión',
#  'leer',
#  'desarrollar',
#  'mitad',
#  'necesitan',
#  'pies',
#  'trabajos',
#  'régimen',
#  'generación',
#  'instituciones',
#  'pedro',
#  'aquella',
#  'fuentes',
#  'restaurante',
#  'salida',
#  'usuario',
#  'destino',
#  'ejercicio',
#  'histórico',
#  'sé',
#  'com',
#  'benedicto',
#  'impuestos',
#  'aumentar',
#  'mental',
#  'evangelio',
#  'obispos',
#  ...]

# %% [markdown]
# ## Almacenamiento de embeddings

# %%
df_vectors = pd.DataFrame(vectors)
df_vectors.to_csv('embeddings.tsv',sep='\t', index=False)

# %%
df_words = pd.DataFrame(words)
df_words.to_csv('labels.tsv',sep='\t', index=False)
